# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Divar.csv',low_memory=False)

# %%
df.shape
# Out:
# (1000000, 61)

# %%
df = df.loc[:,(df.isna().sum()<(df.shape[0]*.7)).values]
df.shape
# Out:
# (1000000, 38)

# %% [markdown]
# ### cat2_slug , cat3_slug

# %%
# df.cat2_slug.value_counts()

# %%
df.cat3_slug.value_counts()
# Out:
# cat3_slug
# apartment-sell                        303385
# apartment-rent                        211880
# plot-old                              133570
# house-villa-sell                      121753
# house-villa-rent                       64678
# shop-rent                              45993
# shop-sell                              21855
# office-rent                            21418
# suite-apartment                        16465
# presell                                15781
# villa                                  12899
# industry-agriculture-business-sell     11851
# industry-agriculture-business-rent      9155
# office-sell                             5155
# partnership                             3622
# workspace                                539
# Name: count, dtype: int64

# %%
mapping = {
    'apartment-sell':'apartment',
    'apartment-rent':'apartment',
    'plot-old':'plot-old',
    'house-villa-sell':'house-villa',
    'house-villa-rent':'house-villa',
    'shop-rent':'shop',
    'shop-sell':'shop',
    'office-rent':'office',
    'office-sell':'office',
    'suite-apartment':'suite-apartment',
    'presell':'presell',
    'villa':'villa',
    'industry-agriculture-business-sell':'industry-agriculture-business',
    'industry-agriculture-business-rent':'industry-agriculture-business',
    'partnership':'partnership',
    'workspace':'workspace'
}

# %%
df['cat3_slug'] = df.cat3_slug.map(mapping)
df.cat3_slug.value_counts()
# Out:
# cat3_slug
# apartment                        515265
# house-villa                      186431
# plot-old                         133570
# shop                              67848
# office                            26573
# industry-agriculture-business     21006
# suite-apartment                   16465
# presell                           15781
# villa                             12899
# partnership                        3622
# workspace                           539
# Name: count, dtype: int64

# %%
df.cat3_slug.value_counts()[df.cat3_slug.value_counts()<10000].index
# Out:
# Index(['partnership', 'workspace'], dtype='object', name='cat3_slug')

# %%
useless_values = df.cat3_slug.value_counts()[df.cat3_slug.value_counts()<1000].index
df = pd.concat([df , pd.get_dummies(df.cat3_slug)] , axis=1).drop(useless_values,axis=1)

# %%
df = df.drop(['cat2_slug','cat3_slug'],axis=1)

# %% [markdown]
# ### city_slug , neighborhood_slug

# %%
city_categorization = pd.read_csv('iran_city_classification.csv')
city_categorization.columns
# Out:
# Index(['نام شهر', 'دسته‌بندی'], dtype='object')

# %%
city_categorization = city_categorization.set_index('نام شهر')

# %%
city_categorization.loc[['tehran','rasht']]
# Out:
#         دسته‌بندی
# نام شهر
# tehran   کلان‌شهر
# rasht    شهر کوچک

# %%
def calcCityCategory(row):
    if row['city_slug'] in city_categorization.index:
        return city_categorization.loc[row['city_slug']]['دسته‌بندی']
    return None

# %%
df['city_category'] = df.apply(calcCityCategory , axis=1)
df.city_category.value_counts()
# Out:
# city_category
# شهر کوچک    498478
# کلان‌شهر    464799
# Name: count, dtype: int64

# %%
df.loc[:,'metropolis'] = df.city_category == 'کلان‌شهر'

# %%
df = df.drop(['city_slug','neighborhood_slug','city_category'] , axis=1)

# %%
df.metropolis.value_counts()
# Out:
# metropolis
# False    535201
# True     464799
# Name: count, dtype: int64

# %% [markdown]
# ### created_at_month

# %%
df.created_at_month = pd.to_datetime(df.created_at_month)
df.loc[:,'created_year'] = df.created_at_month.dt.year
df.loc[:,'created_month'] = df.created_at_month.dt.month
df.created_month.value_counts()
# Out:
# created_month
# 7     133319
# 8     132522
# 10    126606
# 6     125695
# 11    121819
# 9     121615
# 12    116998
# 5     108820
# 4       7215
# 1       2099
# 3       1912
# 2       1380
# Name: count, dtype: int64

# %%
df.created_year.value_counts()
# Out:
# created_year
# 2024    996946
# 2023      1689
# 2025      1292
# 2022        65
# 2021         6
# 2020         2
# Name: count, dtype: int64

# %%
df = df.drop('created_at_month',axis=1)

# %% [markdown]
# ### user_type , description , title

# %%
df = df.drop(['description','title'] , axis=1)

# %% [markdown]
# ### price cols

# %%
print(df.shape)
df = df[(~df.price_value.isna())|((~df.credit_value.isna())&(~df.rent_value.isna()))]
df.shape
# Out:
# (1000000, 44)
# (919538, 44)

# %%
df.loc[:,'is_for_sell'] = ~df.price_value.isna()
df['is_for_sell'].value_counts()
# Out:
# is_for_sell
# True     568346
# False    351192
# Name: count, dtype: int64

# %%
def calcPrice(row):
    if pd.isna(row['price_value']):
        return (row['credit_value'] / 1e6) * 30000 + row['rent_value']
    return row['price_value']
df.loc[:, 'price'] = df.apply(calcPrice, axis=1)
df[['price_value','credit_value','rent_value','price']].head()
# Out:
#     price_value  credit_value  rent_value         price
# 1  8.500000e+09           NaN         NaN  8.500000e+09
# 2           NaN   750000000.0  26000000.0  4.850000e+07
# 3           NaN   950000000.0  95000000.0  1.235000e+08
# 4  5.750000e+09           NaN         NaN  5.750000e+09
# 5           NaN   250000000.0   6000000.0  1.350000e+07

# %%
df = df.drop(['price_value','credit_value','rent_value'] , axis=1)

# %%
def calcMode(row):
    if pd.notna(row['price_mode']):
        return row['price_mode']
    if pd.notna(row['rent_mode']):
        return row['rent_mode']
    return row['credit_mode']
df.loc[:, 'mode'] = df.apply(calcMode , axis=1)
df.loc[:, 'fixed_price'] = df['mode'] == 'مقطوع'
df.fixed_price.value_counts()
# Out:
# fixed_price
# True     858413
# False     61125
# Name: count, dtype: int64

# %%
df = df.drop(['price_mode','rent_mode','credit_mode','mode'] , axis=1)

# %%
df = df.drop(['rent_credit_transform','transformable_price','transformable_credit','transformable_rent'] , axis=1)

# %%
# df.fixed_price.isna().sum()

# %% [markdown]
# ### floor , rooms_count , total_floors_count , unit_per_floor

# %%
def clean_floor(val):
    if pd.isna(val):
        return 0
    val = str(val).strip()
    
    # +30
    if val.endswith('+'):
        return int(val.replace('+', ''))  
    try:
        return int(float(val))  
    except ValueError:
        return np.nan

df.loc[:,'floor'] = df.floor.apply(clean_floor).astype('Int64')
df.floor.value_counts()
# Out:
# floor
# 0     415384
# 2     128170
# 1     119179
# 3     109008
# 4      71694
# 5      37417
# 6      13717
# 7       5674
# -1      4427
# 8       3264
# 10      2284
# 9       2167
# 11      1461
# 12      1224
# 13       826
# 14       780
# 30       735
# 15       447
# 16       310
# 17       268
# 20       212
# 18       186
# 19       151
# 21       115
# 25       102
# 22        87
# 23        76
# 24        61
# 27        35
# 28        32
# 26        25
# 29        20
# Name: count, dtype: int64

# %%
mapping = {
    'بدون اتاق' : 0,
    'یک' : 1,
    'دو' : 2,
    'سه' : 3,
    'چهار' : 4,
    'پنج یا بیشتر' : 5
}
df.loc[:,'rooms_count'] = df.rooms_count.map(mapping)

# %%
df.rooms_count.value_counts()
# Out:
# rooms_count
# 2.0    391251
# 1.0    179542
# 3.0    134634
# 0.0     69430
# 4.0     20335
# 5.0     12588
# Name: count, dtype: int64

# %%
df.loc[:,'rooms_count'] = df.rooms_count.fillna(0)
# Out:
# C:\Users\ROG\AppData\Local\Temp\ipykernel_4480\1454943812.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[:,'rooms_count'] = df.rooms_count.fillna(0)

# %%
df.rooms_count.isna().sum()
# Out:
# 0

# %%
df = df.drop(['total_floors_count','unit_per_floor'] , axis=1)

# %% [markdown]
# ### has...

# %%
df.has_restroom.value_counts()
# Out:
# has_restroom
# squat_seat    219062
# squat         179259
# seat            7409
# unselect         628
# Name: count, dtype: int64

# %%
df.has_restroom.isna().sum()
# Out:
# 513180

# %%
df.loc[:,'has_balcony'] = df.has_balcony.isin(['true','True']).astype(bool)

# %%
df.loc[:, 'has_elevator'] = (df.has_elevator.astype(bool).fillna(False))

# %%
df.loc[:, 'has_warehouse'] = (df.has_warehouse.astype(bool).fillna(False))

# %%
df.loc[:, 'has_parking'] =(df.has_parking.astype(bool).fillna(False))

# %%
df.loc[:,'has_warm_water_provider'] = df.has_warm_water_provider.isin(['package','water_heater','powerhouse']).astype(bool)

# %%
df.loc[:,'has_heating_system'] = df.has_heating_system.isin(['shoofaj','heater','duct_split','floor_heating','split','fan_coil','fireplace']).astype(bool)

# %%
df.loc[:,'has_cooling_system'] = df.has_cooling_system.isin(['water_cooler','air_conditioner','split','duct_split','fan_coil']).astype(bool)

# %%
df.loc[:,'has_restroom'] = df.has_restroom.isin(['squat_seat','squat','seat']).astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919538 entries, 1 to 999999
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     919538 non-null  int64
#  1   building_size                  918254 non-null  float64
#  2   floor                          919538 non-null  object
#  3   rooms_count                    919538 non-null  object
#  4   has_balcony                    919538 non-null  object
#  5   has_elevator                   919538 non-null  object
#  6   has_warehouse                  919538 non-null  object
#  7   has_parking                    919538 non-null  object
#  8   construction_year              807628 non-null  object
#  9   is_rebuilt                     529237 non-null  object
#  10  has_warm_water_provider        919538 non-null  object
#  11  has_heating_system             919538 non-null  object
#  12  has_cooling_system             919538 non-null  object
#  13  has_restroom                   919538 non-null  object
#  14  building_direction             323522 non-null  object
#  15  floor_material                 405436 non-null  object
#  16  location_latitude              606910 non-null  float64
#  17  location_longitude             606910 non-null  float64
#  18  location_radius                323091 non-null  float64
#  19  apartment                      919538 non-null  bool
#  20  house-villa                    919538 non-null  bool
#  21  industry-agriculture-business  919538 non-null  bool
#  22  office                         919538 non-null  bool
#  23  partnership                    919538 non-null  bool
#  24  plot-old                       919538 non-null  bool
#  25  presell                        919538 non-null  bool
#  26  shop                           919538 non-null  bool
#  27  suite-apartment                919538 non-null  bool
#  28  villa                          919538 non-null  bool
#  29  metropolis                     919538 non-null  bool
#  30  created_year                   919538 non-null  int32
#  31  created_month                  919538 non-null  int32
#  32  is_for_sell                    919538 non-null  bool
#  33  price                          919538 non-null  float64
#  34  fixed_price                    919538 non-null  bool
# dtypes: bool(13), float64(5), int32(2), int64(1), object(14)
# memory usage: 165.7+ MB

# %% [markdown]
# ### construction_year , is_rebuilt

# %%
# df.is_rebuilt.value_counts()

# %%
# df.is_rebuilt.isna().sum()

# %%
def convert_persian_year(year_str):
    if pd.isna(year_str):
        return np.nan
    
    year_str = str(year_str).strip()
    
    if 'قبل از ۱۳۷۰' in year_str:
        return 1369  

    persian_to_english = str.maketrans('۰۱۲۳۴۵۶۷۸۹', '0123456789')
    year_english = year_str.translate(persian_to_english)
    year_digits = ''.join(filter(str.isdigit, year_english))
    
    if year_digits:
        return int(year_digits)
    else:
        return np.nan

df.loc[:,'construction_year'] = df['construction_year'].apply(convert_persian_year)

# %%
mode_value = df.construction_year.mode()[0]
df['construction_year'] = (pd.to_numeric(df['construction_year'], errors='coerce').fillna(mode_value).astype('Int64'))

# %%
df['is_rebuilt'] = df['is_rebuilt'].astype('boolean').fillna(False)

# %% [markdown]
# ### building_direction , floor_material

# %%
# df.floor_material.value_counts()

# %%
# df.floor_material.isna().sum()

# %%
df = df.drop(['building_direction','floor_material'],axis=1)

# %% [markdown]
# ### location_latitude , location_longitude , location_radius

# %%
df.location_radius.isna().sum()
# Out:
# 596447

# %%
df = df.drop('location_radius' , axis=1)

# %%
print(df.shape)
df = df.dropna(subset=['location_latitude', 'location_longitude'])
df.shape
# Out:
# (919538, 32)
# (606910, 32)

# %%
df.shape
# Out:
# (606910, 32)

# %%
import geopandas as gpd
from shapely.geometry import Point


gdf = gpd.GeoDataFrame(
    df, 
    geometry=gpd.points_from_xy(df['location_longitude'], df['location_latitude']),
    crs="EPSG:4326"   
)

world = gpd.read_file("ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp")


iran = world[world['NAME'] == "Iran"]

gdf = gdf[gdf.within(iran.iloc[0].geometry)]

df = gdf.drop(columns='geometry')

# %%
df.shape
# Out:
# (602030, 32)

# %%
from pyproj import Transformer
transformer = Transformer.from_crs('epsg:4326','epsg:32639',always_xy=True)

df['utm_x'], df['utm_y'] = transformer.transform(
    df["location_longitude"].values, 
    df["location_latitude"].values
)

df[["location_latitude", "location_longitude", "utm_x", "utm_y"]].head()
# Out:
#     location_latitude  location_longitude          utm_x         utm_y
# 2           35.703865           51.373459  533784.424602  3.951168e+06
# 7           35.729832           51.505466  545711.558185  3.954101e+06
# 8           35.712364           50.794781  481437.130969  3.952066e+06
# 10          35.778664           51.757549  568467.028494  3.959664e+06
# 11          35.733952           51.380608  534418.187237  3.954507e+06

# %%
df = df.drop(['location_latitude','location_longitude'] , axis=1)

# %% [markdown]
# ### land_size , building_size

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
# df.info()

# %%
cols = np.abs(df.drop('price',axis=1).corr()['building_size']).sort_values(ascending=False)[1:16].index

# %%
X_train = df[~df.building_size.isna()][cols]
y_train = df[~df.building_size.isna()]['building_size']

# %%
X_train.isna().sum()
# Out:
# industry-agriculture-business    0
# apartment                        0
# has_heating_system               0
# has_restroom                     0
# has_warm_water_provider          0
# has_cooling_system               0
# has_balcony                      0
# utm_y                            0
# floor                            0
# metropolis                       0
# is_rebuilt                       0
# rooms_count                      0
# has_elevator                     0
# construction_year                0
# has_parking                      0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_missing = df[df.building_size.isna()][cols]
y_pred_missing = linear_regression.predict(X_missing).astype(float)

df.loc[df.building_size.isna(), 'building_size'] = y_pred_missing

# %%
df[df.building_size<0]
# Out:
#         building_size floor rooms_count has_balcony has_elevator  \
# 110286    -175.030532     0         0.0       False         True
# 159292    -180.344848     0         0.0       False         True
# 163070    -173.657421     0         0.0       False         True
# 175855    -181.500639     0         0.0       False         True
# 208206     -76.653513     0         0.0       False         True
# 221321    -147.917362     0         0.0       False         True
# 229215    -164.938727     0         0.0       False         True
# 231124    -310.244286     0         0.0       False         True
# 290965    -147.948898     0         0.0       False         True
# 292507    -175.526991     0         0.0       False         True
# 294252    -167.358800     0         0.0       False         True
# 301746    -171.699009     0         0.0       False         True
# 324780    -170.586902     0         0.0       False         True
# 374698    -150.224306     0         0.0       False         True
# 392783    -173.020611     0         0.0       False         True
# 457089    -161.217047     0         0.0       False         True
# 511043    -169.541592     0         0.0       False         True
# 587203    -163.052392     0         0.0       False         True
# 619221    -149.464166     0         0.0       False         True
# 619888    -154.954692     0         0.0       False         True
# 642831    -147.515326     0         0.0       False         True
# 644257    -175.506445     0         0.0       False         True
# 661915    -164.130282     0         0.0       False         True
# 664616    -153.366884     0         0.0       False         True
# 709128    -147.904660     0         0.0       False         True
# 742380    -174.563222     0         0.0       False         True
# 759029    -179.919115     0         0.0       False         True
# 787118    -181.956705     0         0.0       False         True
# 797750    -169.616417     0         0.0       False         True
# 871098    -185.139508     0         0.0       False         True
# 904505    -149.756471     0         0.0       False         True
# 982600    -167.833939     0         0.0       False         True
# 987803    -313.633935     0         0.0       False         True
# 991441    -161.389037     0         0.0       False         True
#
#        has_warehouse has_parking  construction_year  is_rebuilt  \
# 110286          True        True               1403       False
# 159292          True        True               1403       False
# 163070          True        True               1403       False
# 175855          True        True               1403       False
# 208206          True        True               1403       False
# 221321          True        True               1403       False
# 229215          True        True               1403       False
# 231124          True        True               1403       False
# 290965          True        True               1403       False
# 292507          True        True               1403       False
# 294252          True        True               1403       False
# 301746          True        True               1403       False
# 324780          True        True               1403       False
# 374698          True        True               1403       False
# 392783          True        True               1403       False
# 457089          True        True               1403       False
# 511043          True        True               1403       False
# 587203          True        True               1403       False
# 619221          True        True               1403       False
# 619888          True        True               1403       False
# 642831          True        True               1403       False
# 644257          True        True               1403       False
# 661915          True        True               1403       False
# 664616          True        True               1403       False
# 709128          True        True               1403       False
# 742380          True        True               1403       False
# 759029          True        True               1403       False
# 787118          True        True               1403       False
# 797750          True        True               1403       False
# 871098          True        True               1403       False
# 904505          True        True               1403       False
# 982600          True        True               1403       False
# 987803          True        True               1403       False
# 991441          True        True               1403       False
#
#        has_warm_water_provider  ... suite-apartment  villa metropolis  \
# 110286                   False  ...           False  False       True
# 159292                   False  ...           False  False       True
# 163070                   False  ...           False  False       True
# 175855                   False  ...           False  False       True
# 208206                   False  ...           False  False       True
# 221321                   False  ...           False  False       True
# 229215                   False  ...           False  False       True
# 231124                   False  ...           False  False       True
# 290965                   False  ...           False  False       True
# 292507                   False  ...           False  False       True
# 294252                   False  ...           False  False       True
# 301746                   False  ...           False  False       True
# 324780                   False  ...           False  False       True
# 374698                   False  ...           False  False       True
# 392783                   False  ...           False  False       True
# 457089                   False  ...           False  False       True
# 511043                   False  ...           False  False       True
# 587203                   False  ...           False  False       True
# 619221                   False  ...           False  False       True
# 619888                   False  ...           False  False       True
# 642831                   False  ...           False  False       True
# 644257                   False  ...           False  False       True
# 661915                   False  ...           False  False       True
# 664616                   False  ...           False  False       True
# 709128                   False  ...           False  False       True
# 742380                   False  ...           False  False       True
# 759029                   False  ...           False  False       True
# 787118                   False  ...           False  False       True
# 797750                   False  ...           False  False       True
# 871098                   False  ...           False  False       True
# 904505                   False  ...           False  False       True
# 982600                   False  ...           False  False       True
# 987803                   False  ...           False  False       True
# 991441                   False  ...           False  False       True
#
#         created_year  created_month  is_for_sell         price  fixed_price  \
# 110286          2024              5         True  5.500000e+09         True
# 159292          2024              8         True  3.222500e+09         True
# 163070          2024              7         True  7.770000e+09         True
# 175855          2024              7         True  4.765000e+09         True
# 208206          2024              8         True  6.120000e+09         True
# 221321          2024              6         True  7.600000e+09         True
# 229215          2024              7         True  8.200000e+09         True
# 231124          2024             11         True  9.700000e+09         True
# 290965          2024              7         True  7.140000e+09         True
# 292507          2024              5         True  6.960000e+09         True
# 294252          2024              8         True  6.150000e+09         True
# 301746          2024              7         True  1.745000e+10         True
# 324780          2024              6         True  5.600000e+09         True
# 374698          2024              8         True  1.100000e+10         True
# 392783          2024              8         True  4.600000e+09         True
# 457089          2024              5         True  7.200000e+09         True
# 511043          2024              7         True  1.050000e+10         True
# 587203          2024              7         True  6.400000e+09         True
# 619221          2024              8         True  4.800000e+09         True
# 619888          2024              7         True  3.500000e+09         True
# 642831          2024              8         True  9.240000e+09         True
# 644257          2024              8         True  4.000000e+09         True
# 661915          2024              7         True  6.300000e+09         True
# 664616          2024              5         True  7.200000e+09         True
# 709128          2024              6         True  6.150000e+09         True
# 742380          2024              6         True  6.120000e+09         True
# 759029          2024              7         True  7.600000e+09         True
# 787118          2024              6         True  6.000000e+07         True
# 797750          2024              7         True  5.500000e+09         True
# 871098          2024              4         True  1.050000e+09         True
# 904505          2024              8         True  7.350000e+09         True
# 982600          2024              8         True  4.800000e+09         True
# 987803          2024             11         True  3.550000e+09         True
# 991441          2024              6         True  1.111111e+08         True
#
#                 utm_x         utm_y
# 110286   83033.419851  4.224197e+06
# 159292   85057.777996  4.225587e+06
# 163070   82848.797694  4.223837e+06
# 175855   86166.831063  4.225889e+06
# 208206   91772.843308  4.198462e+06
# 221321   98104.355992  4.217104e+06
# 229215   93059.044795  4.221557e+06
# 231124  532371.374048  3.948387e+06
# 290965   98669.469323  4.217112e+06
# 292507   87198.220490  4.224326e+06
# 294252   94387.744737  4.222190e+06
# 301746   89168.665232  4.223325e+06
# 324780   82767.314995  4.223034e+06
# 374698   97379.644392  4.217708e+06
# 392783   83422.501747  4.223671e+06
# 457089   91427.570047  4.220583e+06
# 511043   86861.214727  4.222761e+06
# 587203   96720.117578  4.221063e+06
# 619221   97356.384550  4.217509e+06
# 619888   92416.264552  4.218945e+06
# 642831   96828.957903  4.216999e+06
# 644257   85650.229907  4.224321e+06
# 661915   95290.902796  4.221345e+06
# 664616   96392.440460  4.218530e+06
# 709128   98102.848434  4.217101e+06
# 742380   83089.941637  4.224074e+06
# 759029   87086.687948  4.225475e+06
# 787118   88015.323730  4.226008e+06
# 797750   94688.115567  4.222780e+06
# 871098   88514.294648  4.226841e+06
# 904505   97329.928791  4.217585e+06
# 982600   95234.655682  4.222314e+06
# 987803  541050.975447  3.949273e+06
# 991441   96289.218100  4.220628e+06
#
# [34 rows x 31 columns]

# %%
df = df[df.building_size>0]

# %% [markdown]
# ### saving

# %%
df.isna().sum()
# Out:
# building_size                    0
# floor                            0
# rooms_count                      0
# has_balcony                      0
# has_elevator                     0
# has_warehouse                    0
# has_parking                      0
# construction_year                0
# is_rebuilt                       0
# has_warm_water_provider          0
# has_heating_system               0
# has_cooling_system               0
# has_restroom                     0
# apartment                        0
# house-villa                      0
# industry-agriculture-business    0
# office                           0
# partnership                      0
# plot-old                         0
# presell                          0
# shop                             0
# suite-apartment                  0
# villa                            0
# metropolis                       0
# created_year                     0
# created_month                    0
# is_for_sell                      0
# price                            0
# fixed_price                      0
# utm_x                            0
# utm_y                            0
# dtype: int64

# %%
# df.info()

# %%
df.describe()
# Out:
#        building_size  construction_year   created_year  created_month  \
# count   6.019960e+05           601996.0  601996.000000  601996.000000
# mean    2.212085e+03        1394.709837    2024.001091       8.579300
# std     9.612007e+04           8.444107       0.046440       2.234786
# min     1.000000e+00             1369.0    2022.000000       1.000000
# 25%     7.300000e+01             1390.0    2024.000000       7.000000
# 50%     1.000000e+02             1397.0    2024.000000       9.000000
# 75%     1.500000e+02             1402.0    2024.000000      10.000000
# max     1.000000e+07             1403.0    2025.000000      12.000000
#
#               price         utm_x         utm_y
# count  6.019960e+05  6.019960e+05  6.019960e+05
# mean   2.299476e+10  5.588312e+05  3.881567e+06
# std    1.751244e+12  2.865385e+05  2.509258e+05
# min    0.000000e+00 -9.094646e+04  2.820041e+06
# 25%    1.900000e+07  4.781838e+05  3.833649e+06
# 50%    1.200000e+09  5.317325e+05  3.953346e+06
# 75%    3.604475e+09  5.705007e+05  4.035999e+06
# max    1.030000e+15  1.661267e+06  4.385966e+06

# %%
df[df.price==0]
# Out:
#         building_size floor rooms_count has_balcony has_elevator  \
# 20              210.0     0         4.0        True         True
# 877             144.0     0         1.0       False         True
# 1243             75.0     1         2.0        True        False
# 1297            200.0     0         3.0        True         True
# 2508             38.0     0         0.0       False        False
# ...               ...   ...         ...         ...          ...
# 995382          200.0     0         2.0        True         True
# 995875          400.0     0         3.0        True         True
# 996500           75.0     1         2.0        True        False
# 998951           90.0     4         2.0        True         True
# 999982          110.0     0         2.0        True         True
#
#        has_warehouse has_parking  construction_year  is_rebuilt  \
# 20              True        True               1403       False
# 877             True       False               1369       False
# 1243            True       False               1395        True
# 1297           False        True               1374       False
# 2508           False       False               1375       False
# ...              ...         ...                ...         ...
# 995382          True        True               1402       False
# 995875          True        True               1400       False
# 996500         False        True               1385        True
# 998951          True        True               1397       False
# 999982          True        True               1396       False
#
#        has_warm_water_provider  ... suite-apartment  villa metropolis  \
# 20                       False  ...           False  False      False
# 877                      False  ...           False  False       True
# 1243                      True  ...           False  False      False
# 1297                      True  ...           False  False      False
# 2508                     False  ...           False  False       True
# ...                        ...  ...             ...    ...        ...
# 995382                   False  ...           False  False       True
# 995875                    True  ...           False  False      False
# 996500                    True  ...           False  False       True
# 998951                    True  ...           False  False       True
# 999982                   False  ...           False  False       True
#
#         created_year  created_month  is_for_sell  price  fixed_price  \
# 20              2024             11         True    0.0        False
# 877             2024             12         True    0.0        False
# 1243            2024              7         True    0.0        False
# 1297            2024             10         True    0.0        False
# 2508            2024              7         True    0.0        False
# ...              ...            ...          ...    ...          ...
# 995382          2024              7         True    0.0        False
# 995875          2024             12         True    0.0        False
# 996500          2024              7         True    0.0        False
# 998951          2024              9         True    0.0        False
# 999982          2024              7         True    0.0        False
#
#                utm_x         utm_y
# 20      3.574301e+05  3.702682e+06
# 877     1.384972e+05  3.803624e+06
# 1243    3.506455e+05  4.121707e+06
# 1297    8.521016e+05  3.153935e+06
# 2508    1.405776e+05  3.807576e+06
# ...              ...           ...
# 995382  2.713091e+05  3.471076e+06
# 995875  5.098659e+05  4.060758e+06
# 996500  1.264437e+06  4.059464e+06
# 998951  4.830012e+05  3.822757e+06
# 999982  6.029463e+05  3.335005e+06
#
# [1191 rows x 31 columns]

# %%
df.to_csv('Divar_preproccessed.csv')
